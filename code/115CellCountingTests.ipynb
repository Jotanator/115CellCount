# %%
# !git clone https://github.com/Jotanator/115CellCount.git
# Out:
# fatal: destination path '115CellCount' already exists and is not an empty directory.

# %%
# !cd 115CellCount && git reset --hard
# Out:
# HEAD is now at fb2f7ec shorten training

# %%
# !cd 115CellCount && git pull origin mlScripts
# Out:
# From https://github.com/Jotanator/115CellCount
#  * branch            mlScripts  -> FETCH_HEAD
# Updating fb2f7ec..a41c534
# Fast-forward
#  .gitignore    |  2 +-
#  code/model.py | 13 +++++++++++++
#  code/run.py   | 17 +++++++++++++++++
#  3 files changed, 31 insertions(+), 1 deletion(-)

# %%
# !cd 115CellCount && git checkout mlScripts
# Out:
# Branch 'mlScripts' set up to track remote branch 'mlScripts' from 'origin'.
# Switched to a new branch 'mlScripts'

# %%
# !cd 115CellCount/code && python run.py
# Out:
# 2021-04-30 23:18:58.116947: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# training images found:  ['../data/train/92.1 cells (092820, P15, 20X, S2).jpg', '../data/train/92.1 cells (092820, P11, 20X, S2).jpg', '../data/train/92.1 cells (092820, P12, 20X, S2).jpg', '../data/train/92.1 cells (092820, P14, 20X, S2).jpg']
# argument passed into load_image_list:  ['../data/train/92.1 cells (092820, P15, 20X, S2).jpg', '../data/train/92.1 cells (092820, P11, 20X, S2).jpg', '../data/train/92.1 cells (092820, P12, 20X, S2).jpg', '../data/train/92.1 cells (092820, P14, 20X, S2).jpg']
# imgs at the end of load_image_list:  [array([[[180, 194, 200],
#         [180, 194, 200],
#         [181, 193, 199],
#         ...,
#         [176, 175, 184],
#         [177, 176, 186],
#         [178, 177, 187]],
#
#        [[182, 196, 202],
#         [182, 196, 202],
#         [183, 195, 201],
#         ...,
#         [177, 176, 185],
# ...
